# %% [markdown]
# # 04 - Feature Matching & Spatial Distribution Analysis
#
# Inspect inlier clusters, Delaunay triangulation coverage, and 8x8 spatial grid metrics.

# %%
import numpy as np
import matplotlib.pyplot as plt

print("Spatial matching analysis ready.")
