# %% [markdown]
# # 06 - Scale-Invariance & Multi-Resolution Pyramids
#
# Evaluate registration across severe scale disparities (OHRC 0.25m vs TMC-2 5.0m = 20x jump).

# %%
import numpy as np

print("Scale invariance module ready.")
