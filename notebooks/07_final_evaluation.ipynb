# %% [markdown]
# # 07 - Final Evaluation & Benchmark Dashboard
#
# Aggregate benchmark results across locked test pairs and generate evaluation figures.

# %%
from scripts.evaluate import load_metric_files, summarize_metrics
from pathlib import Path

results = load_metric_files(Path("outputs/metrics"))
summarize_metrics(results)
