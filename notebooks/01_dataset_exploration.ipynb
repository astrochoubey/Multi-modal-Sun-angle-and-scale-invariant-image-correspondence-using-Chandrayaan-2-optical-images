# %% [markdown]
# # 01 - Planetary Dataset & Metadata Exploration
#
# Explore Chandrayaan-2 (OHRC, TMC-2, IIRS) and NASA LRO NAC metadata from `data/manifests/pilot_manifest.csv`.

# %%
import pandas as pd
import matplotlib.pyplot as plt

manifest = pd.read_csv("data/manifests/pilot_manifest.csv")
manifest.head()
