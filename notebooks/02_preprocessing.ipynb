# %% [markdown]
# # 02 - Photometric Normalization & CLAHE
#
# Evaluate 16-bit percentile normalization and CLAHE local contrast enhancement.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from lunar_registration.preprocessing.preprocessing import preprocess, to_grayscale, apply_clahe

print("Preprocessing module ready.")
