# %% [markdown]
# # 05 - Sun-Angle & Illumination Invariance Benchmark
#
# Assess keypoint repeatability and inlier ratio against solar azimuth difference (Delta phi).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Illumination invariance benchmark ready.")
